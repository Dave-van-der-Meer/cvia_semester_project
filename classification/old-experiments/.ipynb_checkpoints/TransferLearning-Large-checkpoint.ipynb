# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# create a data generator
datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=90,
    brightness_range=[1.0, 1.75],
    zoom_range=[0.5, 1.0],
    horizontal_flip = True,
    validation_split=0.2)

# load and iterate training dataset
train_it = datagen.flow_from_directory(
    '../master-data/train_small/rgb', 
    target_size=(224, 224),
    subset="training", 
    class_mode="categorical",
    shuffle=True,
    batch_size=256)

val_it = datagen.flow_from_directory(
    '../master-data/train_small/rgb', 
    target_size=(224, 224), 
    subset="validation", 
    class_mode="categorical",
    shuffle=True,
    batch_size=256)
# Out:
# Found 24010 images belonging to 11 classes.
# Found 6001 images belonging to 11 classes.

# %%
def plot_history(history):
    '''Plot loss and accuracy as a function of the epoch,
    for the training and validation datasets.
    '''
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Get number of epochs
    epochs = range(len(acc))

    # Plot training and validation accuracy per epoch
    plt.plot(epochs, acc, label="acc")
    plt.plot(epochs, val_acc, label="val_acc")
    plt.title('Training and validation accuracy')
    plt.legend()
    
    # Plot training and validation loss per epoch
    plt.figure()

    plt.plot(epochs, loss, label="loss")
    plt.plot(epochs, val_loss, label="val_loss")
    plt.title('Training and validation loss')
    plt.legend()
    
    plt.show()

# %%
conv_model = VGG16(weights='imagenet', include_top=False, classes=11, input_shape=(224,224,3))
# conv_model.summary()
# Out:
# 2021-11-22 03:54:42.209426: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-11-22 03:54:42.471932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:1a:00.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-11-22 03:54:42.473546: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 1 with properties:
# pciBusID: 0000:1c:00.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-11-22 03:54:42.475090: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 2 with properties:
# pciBusID: 0000:1d:00.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-11-22 03:54:42.496449: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-22 03:54:42.583691: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-11-22 03:54:42.598254: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-11-22 03:54:42.613494: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-11-22 03:54:42.635297: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-11-22 03:54:42.665592: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-11-22 03:54:42.704837: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-11-22 03:54:42.714870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0, 1, 2
# 2021-11-22 03:54:42.716477: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-11-22 03:54:42.732974: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2600000000 Hz
# 2021-11-22 03:54:42.733898: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x4a98ca0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-11-22 03:54:42.733929: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-11-22 03:54:43.148728: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x4b0eca0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-11-22 03:54:43.148777: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2021-11-22 03:54:43.148833: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2021-11-22 03:54:43.148848: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2021-11-22 03:54:43.153011: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:1a:00.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-11-22 03:54:43.153922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 1 with properties:
# pciBusID: 0000:1c:00.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-11-22 03:54:43.154812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 2 with properties:
# pciBusID: 0000:1d:00.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-11-22 03:54:43.154854: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-22 03:54:43.154868: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-11-22 03:54:43.154880: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-11-22 03:54:43.154892: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-11-22 03:54:43.154903: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-11-22 03:54:43.154914: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-11-22 03:54:43.154926: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-11-22 03:54:43.160100: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0, 1, 2
# 2021-11-22 03:54:43.160207: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-22 03:54:43.163438: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-11-22 03:54:43.163455: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0 1 2
# 2021-11-22 03:54:43.163488: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N Y Y
# 2021-11-22 03:54:43.163495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 1:   Y N Y
# 2021-11-22 03:54:43.163501: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 2:   Y Y N
# 2021-11-22 03:54:43.167422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14900 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:1a:00.0, compute capability: 7.0)
# 2021-11-22 03:54:43.168944: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 14900 MB memory) -> physical GPU (device: 1, name: Tesla V100-SXM2-16GB, pci bus id: 0000:1c:00.0, compute capability: 7.0)
# 2021-11-22 03:54:43.170287: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 14900 MB memory) -> physical GPU (device: 2, name: Tesla V100-SXM2-16GB, pci bus id: 0000:1d:00.0, compute capability: 7.0)

# %%
for layer in conv_model.layers:
    layer.trainable = False

# flatten the output of the convolutional part: 
x = Flatten()(conv_model.output)
# three hidden layers
x = Dense(100, activation='relu')(x)
x = Dense(100, activation='relu')(x)
x = Dense(100, activation='relu')(x)

# final softmax layer
predictions = Dense(11, activation='softmax')(x)

# creating the full model:
full_model = Model(inputs=conv_model.input, outputs=predictions)
full_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None,
100
# 94/94 [==============================] - 194s 2s/step - loss: 0.8073 - acc: 0.7199 - val_loss: 1.5401 - val_acc: 0.5452
# Epoch 91/100
# 94/94 [==============================] - 197s 2s/step - loss: 0.8084 - acc: 0.7236 - val_loss: 1.4624 - val_acc: 0.5897
# Epoch 92/100
# 94/94 [==============================] - 194s 2s/step - loss: 0.8005 - acc: 0.7268 - val_loss: 1.4417 - val_acc: 0.5891
# Epoch 93/100
# 94/94 [==============================] - 195s 2s/step - loss: 0.7860 - acc: 0.7244 - val_loss: 1.4348 - val_acc: 0.5687
# Epoch 94/100
# 94/94 [==============================] - 203s 2s/step - loss: 0.8012 - acc: 0.7214 - val_loss: 1.5063 - val_acc: 0.5792
# Epoch 95/100
# 94/94 [==============================] - 207s 2s/step - loss: 0.8004 - acc: 0.7206 - val_loss: 1.4534 - val_acc: 0.5607
# Epoch 96/100
# 94/94 [==============================] - 206s 2s/step - loss: 0.7974 - acc: 0.7227 - val_loss: 1.5461 - val_acc: 0.5584
# Epoch 97/100
# 94/94 [==============================] - 206s 2s/step - loss: 0.7930 - acc: 0.7275 - val_loss: 1.5166 - val_acc: 0.5832
# Epoch 98/100
# 94/94 [==============================] - 205s 2s/step - loss: 0.8109 - acc: 0.7180 - val_loss: 1.4562 - val_acc: 0.5889
# Epoch 99/100
# 94/94 [==============================] - 205s 2s/step - loss: 0.7775 - acc: 0.7313 - val_loss: 1.4656 - val_acc: 0.5792
# Epoch 100/100
# 94/94 [==============================] - 210s 2s/step - loss: 0.7778 - acc: 0.7305 - val_loss: 1.5604 - val_acc: 0.5674

# %%
plot_history(history)

# %%
full_model.save_weights('vgg16-weights.h5')
full_model.save('vgg16-model')
# Out:
# 2021-11-22 10:06:52.552391: W tensorflow/python/util/util.cc:329] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /mnt/irisgpfs/users/tdejesus/venv/tiago_env/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: vgg16-model/assets

# %%
conv_model = VGG16(weights='imagenet', include_top=False, input_shape=(224,224,3))

for layer in conv_model.layers:
    layer.trainable = False
    
# flatten the output of the convolutional part: 
x = Flatten()(conv_model.output)
x = Dense(100, activation='relu')(x)
x = Dense(100, activation='relu')(x)
x = Dense(100, activation='relu')(x)
predictions = Dense(11, activation='softmax')(x)

# creating the full model:
full_model = Model(inputs=conv_model.input, outputs=predictions)
full_model.load_weights('vgg16.h5')


from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input

img_path = '../master-data/train_small/rgb/Aquarius/image_00003_img.png'
img = image.load_img(img_path, target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
predict = full_model.predict(x).argmax(axis=1)
print(predict)
plt.imshow(img)
# Out:
# [0]

# %%
classes = train_it.class_indices
classes
# Out:
# {'AcrimSat': 0,
#  'Aquarius': 1,
#  'Aura': 2,
#  'Calipso': 3,
#  'Cloudsat': 4,
#  'CubeSat': 5,
#  'Debris': 6,
#  'Jason': 7,
#  'Sentinel-6': 8,
#  'TRMM': 9,
#  'Terra': 10}

# %%
print(f'Class Predicted ---- {list(classes)[predict[0]]}')
# Out:
# Class Predicted ---- AcrimSat
